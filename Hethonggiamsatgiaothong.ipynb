# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.135-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...

# %%
import os
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('/content/drive/MyDrive/Hethonggiamsatgiaothong/yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 227MB/s]

# %%
model.train(
    data='/content/drive/MyDrive/Hethonggiamsatgiaothong/ultralytics/data/Data/data.yaml',
    epochs=50,
    name='/content/drive/MyDrive/Hethonggiamsatgiaothong/smakt_scanner'
)
# Out:
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab.patches import cv2_imshow
import cv2

def show_image(pth):
  img = cv2.imread(pth)
  cv2_imshow(img)

  return None

# %%
show_image("/content/drive/MyDrive/Hethonggiamsatgiaothong/smakt_scanner/results.png")
# Out:
# <PIL.Image.Image image mode=RGB size=2400x1200>

# %%
show_image("/content/drive/MyDrive/Hethonggiamsatgiaothong/smakt_scanner/confusion_matrix.png")
# Out:
# <PIL.Image.Image image mode=RGB size=3000x2250>

# %%
model = YOLO("/content/drive/MyDrive/Hethonggiamsatgiaothong/smakt_scanner/weights/best.pt")
model.val(split="test")
# Out:
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 12.4±4.5 MB/s, size: 73.7 KB)
# val: Scanning /content/drive/MyDrive/Hethonggiamsatgiaothong/ultralytics/data/Data/test/labels... 611 images, 6 backgrounds, 0 corrupt: 100%|██████████| 611/611 [00:06<00:00, 96.76it/s]
# val: New cache created: /content/drive/MyDrive/Hethonggiamsatgiaothong/ultralytics/data/Data/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 44, len(boxes) = 6329. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:11<00:00,  3.53it/s]
# ...

# %%
show_image("/content/drive/MyDrive/Hethonggiamsatgiaothong/smakt_scanner/val_batch0_labels.jpg")
show_image("/content/drive/MyDrive/Hethonggiamsatgiaothong/smakt_scanner/val_batch1_labels.jpg")
show_image("/content/drive/MyDrive/hethonggiamsatxa/YOLOv8/smakt_scanner/val_batch2_labels.jpg")

# %%
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2881) /content/drive/MyDrive/Hethonggiamsatgiaothong/video.mp4: 640x384 3 cars, 54.2ms
# video 1/1 (frame 2/2881) /content/drive/MyDrive/Hethonggiamsatgiaothong/video.mp4: 640x384 3 cars, 7.2ms
# video 1/1 (frame 3/2881) /content/drive/MyDrive/Hethonggiamsatgiaothong/video.mp4: 640x384 1 bus, 3 cars, 7.8ms
# ...

# %%
import os
os.listdir("/content/runs/detect/predict2")
